# %%
import random
l=["rock","paper","scissor"]
ucount=0
ccount=0
while True:
    choice=int(input('''
    game start------
    1.yes
    2.no
    '''))
    if choice==1:
        for a in range(1,6):
            userinput=int(input('''
            1.rock
            2.paper
            3.scissor
            '''))
            if userinput==1:
                u_choice="rock"
            elif userinput==2:
                u_choice="paper"
            elif userinput==3:
                u_choice="scissor"
            c_choice=random.choice(l)
            print(c_choice)
            if u_choice==c_choice:
                print("your choice is",u_choice)
                print("computer choice is",c_choice)
                print("match is draw")
            elif (u_choice=="rock" and c_choice=="scissor") or (u_choice=="paper" and c_choice=="rock") or(u_choice=="scissor" and c_choice=="paper"):
                print("your choice is ",u_choice)
                print("computer choice is",c_choice)
                print("you win the match")
                ucount=ucount+1
            else:
                print("your choice is",u_choice)
                print("computer choice is",c_choice)
                print("computer win the match")
                ccount=ccount+1
        if ccount==ucount:
           print("your score is",ucount)
           print("computer score is",ccount)
           print("final match is draw")

        elif ucount>ccount:
           print("your score is",ucount)
           print("computer score is",ccount)
           print("you won the final match")

        else:
           print("your score is",ucount)
           print("computer score is",ccount)
           print("computer won the final match")



    else:
        break
# Out:
#     game start------
#     1.yes
#     2.no
#     1
#
#             1.rock
#             2.paper
#             3.scissor
#             1
# rock
# your choice is rock
# computer choice is rock
# match is draw
#
#             1.rock
#             2.paper
#             3.scissor
#             2
# rock
# your choice is  paper
# computer choice is rock
# you win the match
#
#             1.rock
#             2.paper
#             3.scissor
#             3
# rock
# your choice is scissor
# computer choice is rock
# computer win the match
#
#             1.rock
#             2.paper
#             3.scissor
#             1
# rock
# your choice is rock
# computer choice is rock
# match is draw
#
#             1.rock
#             2.paper
#             3.scissor
#             2
# rock
# your choice is  paper
# computer choice is rock
# you win the match
# your score is 2
# computer score is 1
# you won the final match
#
#     game start------
#     1.yes
#     2.no
#     2
